# %%
from sentence_transformers import SentenceTransformer

# Tải mô hình embedding
model = SentenceTransformer("all-MiniLM-L6-v2")

# Văn bản đầu vào
text = "Trí tuệ nhân tạo đang thay đổi cách chúng ta làm việc."

# Chuyển văn bản thành vector embedding
embedding = model.encode(text)

print("Văn bản:")
print(text)

print("\nKích thước vector:")
print(embedding.shape)

print("\n20 giá trị đầu tiên của embedding:")
print(embedding[:20])
# Out:
# Văn bản:
# Trí tuệ nhân tạo đang thay đổi cách chúng ta làm việc.
#
# Kích thước vector:
# (384,)
#
# 10 giá trị đầu tiên của embedding:
# [-0.13338879  0.0491513  -0.03365028 -0.03666853 -0.06170413 -0.00645645
#   0.05397162  0.03702312  0.07289031 -0.02189906  0.16294505 -0.14398411
#  -0.05772502 -0.07088229  0.02851278 -0.05423268 -0.06174118  0.08485091
#  -0.01441087 -0.06494691]
